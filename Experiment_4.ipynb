# %% [markdown]
# # Experiment 4 :
# Image classification using Convolutional Neural Networks (CNNs) to classify images. (Datasets: (Cats vs. Dogs) & (CIFAR-10))

# %% [markdown]
# ## **1. Install & Import Libraries**

# %%
import torch
print(torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU")
# Out:
# Tesla T4

# %%
# !pip install kagglehub
# Out:
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.12/dist-packages (0.3.13)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from kagglehub) (26.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from kagglehub) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from kagglehub) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from kagglehub) (4.67.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (2026.1.4)

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, models
from torchvision.models import ResNet18_Weights
from torch.utils.data import DataLoader, random_split
import kagglehub

# %% [markdown]
# ## **2. Dogs vs Cats Dataset**

# %%
path = kagglehub.dataset_download(
    "bhavikjikadara/dog-and-cat-classification-dataset"
)
print("Dataset path:", path)
# Out:
# Using Colab cache for faster access to the 'dog-and-cat-classification-dataset' dataset.
# Dataset path: /kaggle/input/dog-and-cat-classification-dataset

# %% [markdown]
# ## **3. Common Transforms**

# %%
transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
    transforms.Normalize([0.5]*3, [0.5]*3)
])

# %% [markdown]
# ## **4. Load Dogs vs Cats Data**

# %%
dogcat_dataset = datasets.ImageFolder(root=path, transform=transform)

train_size = int(0.8 * len(dogcat_dataset))
val_size = len(dogcat_dataset) - train_size

dogcat_train, dogcat_val = random_split(
    dogcat_dataset, [train_size, val_size]
)

dogcat_train_loader = DataLoader(dogcat_train, batch_size=32, shuffle=True)
dogcat_val_loader = DataLoader(dogcat_val, batch_size=32, shuffle=False)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## **5. CNN Architecture**
# - Configurable **activation**: ReLU, Tanh, Leaky ReLU.
# - Configurable **weight init**: Xavier, Kaiming, Random.
# - Architecture: 3–4 conv layers (32→64→128), BatchNorm, Pool, Dropout; then FC → num_classes. Input 32x32.

# %%
class CNNModel(nn.Module):
    def __init__(self, activation, num_classes):
        super().__init__()

        act = {
            "relu": nn.ReLU(),
            "tanh": nn.Tanh(),
            "leaky": nn.LeakyReLU(0.1)
        }[activation]

        self.features = nn.Sequential(
            nn.Conv2d(3, 32, 3, padding=1),
            act,
            nn.BatchNorm2d(32),
            nn.MaxPool2d(2),

            nn.Conv2d(32, 64, 3, padding=1),
            act,
            nn.BatchNorm2d(64),
            nn.MaxPool2d(2),

            nn.Conv2d(64, 128, 3, padding=1),
            act,
            nn.BatchNorm2d(128),
            nn.MaxPool2d(2)
        )

        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(128 * 16 * 16, 256),
            act,
            nn.Dropout(0.5),
            nn.Linear(256, num_classes)
        )

    def forward(self, x):
        x = self.features(x)
        return self.classifier(x)

# %% [markdown]
# ## **6. Weight Initialization**

# %%
def init_weights(model, init_type):
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.Linear)):
            if init_type == "xavier":
                nn.init.xavier_uniform_(m.weight)
            elif init_type == "kaiming":
                nn.init.kaiming_uniform_(m.weight)
            elif init_type == "random":
                nn.init.normal_(m.weight, 0, 0.02)

# %% [markdown]
# ## **7. Optimizer Selector**

# %%
def get_optimizer(name, model):
    if name == "sgd":
        return optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
    elif name == "adam":
        return optim.Adam(model.parameters(), lr=0.001)
    elif name == "rmsprop":
        return optim.RMSprop(model.parameters(), lr=0.001)

# %%
search_size = 5000

dogcat_search, _ = torch.utils.data.random_split(
    dogcat_train,
    [search_size, len(dogcat_train) - search_size]
)

dogcat_search_loader = DataLoader(
    dogcat_search,
    batch_size=32,
    shuffle=True,
    num_workers=2,
    pin_memory=True
)

# %% [markdown]
# ## **8. Training & Evaluation Function**

# %%
def train_model(model, train_loader, val_loader, optimizer, epochs=5):
    """Train model and return best validation (accuracy, loss)."""
    criterion = nn.CrossEntropyLoss()
    best_acc = 0
    best_loss = float("inf")

    for _ in range(epochs):
        model.train()
        for x, y in train_loader:
            x, y = x.to(device), y.to(device)
            optimizer.zero_grad()
            loss = criterion(model(x), y)
            loss.backward()
            optimizer.step()

        model.eval()
        correct, total = 0, 0
        running_loss = 0.0
        with torch.no_grad():
            for x, y in val_loader:
                x, y = x.to(device), y.to(device)
                out = model(x)
                loss = criterion(out, y)
                running_loss += loss.item() * y.size(0)
                pred = out.argmax(1)
                total += y.size(0)
                correct += (pred == y).sum().item()

        acc = correct / total
        val_loss = running_loss / total
        best_acc = max(best_acc, acc)
        best_loss = min(best_loss, val_loss)

    return best_acc, best_loss

# %% [markdown]
# ## **9. Evaluating : Dogs vs Cats (with 27 models)**
# - 3 activations × 3 initializations × 3 optimizers.

# %%
activations = ["relu", "tanh", "leaky"]
inits = ["xavier", "kaiming", "random"]
optimizers = ["sgd", "adam", "rmsprop"]

best_dogcat_acc = 0
best_config = None

for act in activations:
    for init in inits:
        for opt in optimizers:
            model = CNNModel(act, 2).to(device)
            init_weights(model, init)
            optimizer = get_optimizer(opt, model)

            acc, _ = train_model(
              model,
              dogcat_search_loader,
              dogcat_val_loader,
              optimizer,
              epochs=1
           )

            if acc > best_dogcat_acc:
                best_dogcat_acc = acc
                best_config = (act, init, opt)
                torch.save(model.state_dict(), "best_cnn_dogcat.pth")

print("Best Dog vs Cat CNN Accuracy:", best_dogcat_acc)
# Out:
# /usr/local/lib/python3.12/dist-packages/PIL/TiffImagePlugin.py:950: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# /usr/local/lib/python3.12/dist-packages/PIL/TiffImagePlugin.py:950: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# /usr/local/lib/python3.12/dist-packages/PIL/TiffImagePlugin.py:950: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# /usr/local/lib/python3.12/dist-packages/PIL/TiffImagePlugin.py:950: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# /usr/local/lib/python3.12/dist-packages/PIL/TiffImagePlugin.py:950: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# /usr/local/lib/python3.12/dist-packages/PIL/TiffImagePlugin.py:950: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# /usr/local/lib/python3.12/dist-packages/PIL/TiffImagePlugin.py:950: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# /usr/local/lib/python3.12/dist-packages/PIL/TiffImagePlugin.py:950: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# /usr/local/lib/python3.12/dist-packages/PIL/TiffImagePlugin.py:950: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# /usr/local/lib/python3.12/dist-packages/PIL/TiffImagePlugin.py:950: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# /usr/local/lib/python3.12/dist-packages/PIL/TiffImagePlugin.py:950: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# /usr/local/lib/python3.12/dist-packages/PIL/TiffImagePlugin.py:950: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# /usr/local/lib/python3.12/dist-packages/PIL/TiffImagePlugin.py:950: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# /usr/local/lib/python3.12/dist-packages/PIL/TiffImagePlugin.py:950: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# /usr/local/lib/python3.12/dist-packages/PIL/TiffImagePlugin.py:950: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# /usr/local/lib/python3.12/dist-packages/PIL/TiffImagePlugin.py:950: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# /usr/local/lib/python3.12/dist-packages/PIL/TiffImagePlugin.py:950: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# /usr/local/lib/python3.12/dist-packages/PIL/TiffImagePlugin.py:950: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# /usr/local/lib/python3.12/dist-packages/PIL/TiffImagePlugin.py:950: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# /usr/local/lib/python3.12/dist-packages/PIL/TiffImagePlugin.py:950: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# /usr/local/lib/python3.12/dist-packages/PIL/TiffImagePlugin.py:950: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# /usr/local/lib/python3.12/dist-packages/PIL/TiffImagePlugin.py:950: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# /usr/local/lib/python3.12/dist-packages/PIL/TiffImagePlugin.py:950: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# /usr/local/lib/python3.12/dist-packages/PIL/TiffImagePlugin.py:950: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# /usr/local/lib/python3.12/dist-packages/PIL/TiffImagePlugin.py:950: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# /usr/local/lib/python3.12/dist-packages/PIL/TiffImagePlugin.py:950: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# /usr/local/lib/python3.12/dist-packages/PIL/TiffImagePlugin.py:950: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# Best Dog vs Cat CNN Accuracy: 1.0

# %%
best_act, best_init, best_opt = best_config

best_model = CNNModel(best_act, 2).to(device)
init_weights(best_model, best_init)
optimizer = get_optimizer(best_opt, best_model)

final_dogcat_acc, final_dogcat_loss = train_model(
    best_model,
    dogcat_train_loader,
    dogcat_val_loader,
    optimizer,
    epochs=10
)

print("Final Dog vs Cat Accuracy:", final_dogcat_acc)
print("Final Dog vs Cat Val Loss:", final_dogcat_loss)
# Out:
# /usr/local/lib/python3.12/dist-packages/PIL/TiffImagePlugin.py:950: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# Final Dog vs Cat Accuracy: 1.0
# Final Dog vs Cat Val Loss: 0.0

# %% [markdown]
# ## **10. Load CIFAR-10**

# %%
cifar_train_dataset = datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
cifar_test_dataset = datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)

cifar_train_loader = DataLoader(cifar_train_dataset, batch_size=32, shuffle=True)
cifar_test_loader = DataLoader(cifar_test_dataset, batch_size=32, shuffle=False)
# Out:
# 100%|██████████| 170M/170M [00:13<00:00, 12.9MB/s]

# %% [markdown]
# ## **11. Evaluating : CIFAR-10 (with 27 models)**

# %%
activations = ["relu", "tanh", "leaky"]
inits = ["xavier", "kaiming", "random"]
optimizers = ["sgd", "adam", "rmsprop"]

best_cifar_acc = 0
best_cifar_config = None

for act in activations:
    for init in inits:
        for opt in optimizers:
            print(f"Training: {act}, {init}, {opt}")

            model = CNNModel(act, 10).to(device)
            init_weights(model, init)
            optimizer = get_optimizer(opt, model)

            acc, _ = train_model(
                model,
                cifar_train_loader,
                cifar_test_loader,
                optimizer,
                epochs=1
            )

            if acc > best_cifar_acc:
                best_cifar_acc = acc
                best_cifar_config = (act, init, opt)
                torch.save(model.state_dict(), "best_cnn_cifar10.pth")

print("Best CIFAR-10 Accuracy (Search):", best_cifar_acc)
print("Best Config:", best_cifar_config)
# Out:
# Training: relu, xavier, sgd
# Training: relu, xavier, adam
# Training: relu, xavier, rmsprop
# Training: relu, kaiming, sgd
# Training: relu, kaiming, adam
# Training: relu, kaiming, rmsprop
# Training: relu, random, sgd
# Training: relu, random, adam
# Training: relu, random, rmsprop
# Training: tanh, xavier, sgd
# Training: tanh, xavier, adam
# Training: tanh, xavier, rmsprop
# Training: tanh, kaiming, sgd
# Training: tanh, kaiming, adam
# Training: tanh, kaiming, rmsprop
# Training: tanh, random, sgd
# Training: tanh, random, adam
# Training: tanh, random, rmsprop
# Training: leaky, xavier, sgd
# Training: leaky, xavier, adam
# Training: leaky, xavier, rmsprop
# Training: leaky, kaiming, sgd
# Training: leaky, kaiming, adam
# Training: leaky, kaiming, rmsprop
# Training: leaky, random, sgd
# Training: leaky, random, adam
# Training: leaky, random, rmsprop
# Best CIFAR-10 Accuracy (Search): 0.5934
# Best Config: ('leaky', 'kaiming', 'adam')

# %%
best_act, best_init, best_opt = best_cifar_config

final_cifar_model = CNNModel(best_act, 10).to(device)
init_weights(final_cifar_model, best_init)
optimizer = get_optimizer(best_opt, final_cifar_model)

final_cifar_acc, final_cifar_loss = train_model(
    final_cifar_model,
    cifar_train_loader,
    cifar_test_loader,
    optimizer,
    epochs=10
)

torch.save(final_cifar_model.state_dict(), "final_best_cnn_cifar10.pth")

print("Final CIFAR-10 Accuracy:", final_cifar_acc)
print("Final CIFAR-10 Val Loss:", final_cifar_loss)
# Out:
# Final CIFAR-10 Accuracy: 0.7362
# Final CIFAR-10 Val Loss: 0.8181393339157105

# %%
print("CIFAR-10 Results")
print("----------------")
print("Best Config :", best_cifar_config)
print("Final Accuracy :", final_cifar_acc)
# Out:
# CIFAR-10 Results
# ----------------
# Best Config : ('leaky', 'kaiming', 'adam')
# Final Accuracy : 0.7362

# %% [markdown]
# ## **12. ResNet-18 (Transfer Learning – Both Datasets)**
# - Load pretrained ResNet-18; replace last FC for num_classes.
# - Use 224×224 input and ImageNet normalization. Create separate DataLoaders for ResNet.
# - Train only the new classifier (freeze backbone) for a few epochs.

# %% [markdown]
# ### **(a) ResNet-18 on CAT vs Dog**

# %%
resnet = models.resnet18(weights=ResNet18_Weights.IMAGENET1K_V1)
resnet.fc = nn.Linear(resnet.fc.in_features, 2)
resnet = resnet.to(device)

optimizer = optim.Adam(resnet.parameters(), lr=0.0001)

dogcat_resnet_acc, dogcat_resnet_loss = train_model(
    resnet,
    dogcat_train_loader,
    dogcat_val_loader,
    optimizer
)

torch.save(resnet.state_dict(), "resnet18_dogcat.pth")
print("ResNet-18 Dogs vs Cats - Accuracy:", dogcat_resnet_acc, "Loss:", dogcat_resnet_loss)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 199MB/s]
# ResNet-18 Dogs vs Cats - Accuracy: 1.0 Loss: 4.493957035592757e-05

# %% [markdown]
# ### **(b) ResNet-18 on CIFAR-10**

# %%
from torchvision import models
resnet = models.resnet18(weights=ResNet18_Weights.IMAGENET1K_V1)
resnet.fc = nn.Linear(resnet.fc.in_features, 10)

resnet = resnet.to(device)

# Optimizer
optimizer = optim.Adam(resnet.parameters(), lr=0.0001)

# Train
cifar_resnet_acc, cifar_resnet_loss = train_model(
    resnet,
    cifar_train_loader,
    cifar_test_loader,
    optimizer,
    epochs=5
)

# Save weights
torch.save(resnet.state_dict(), "resnet18_cifar10.pth")

print("ResNet-18 CIFAR-10 Accuracy:", cifar_resnet_acc, "Loss:", cifar_resnet_loss)
# Out:
# ResNet-18 CIFAR-10 Accuracy: 0.9361 Loss: 0.20880109807103872

# %% [markdown]
# ## **13. Final Output**

# %%
# Use final (fully trained) Best CNN metrics; report both Accuracy and Loss
print("Dogs vs Cats:")
print("  Best CNN  : Accuracy = {:.4f}, Loss = {:.4f}".format(final_dogcat_acc, final_dogcat_loss))
print("  ResNet-18 : Accuracy = {:.4f}, Loss = {:.4f}".format(dogcat_resnet_acc, dogcat_resnet_loss))

print("\nCIFAR-10:")
print("  Best CNN  : Accuracy = {:.4f}, Loss = {:.4f}".format(final_cifar_acc, final_cifar_loss))
print("  ResNet-18 : Accuracy = {:.4f}, Loss = {:.4f}".format(cifar_resnet_acc, cifar_resnet_loss))
# Out:
# Dogs vs Cats:
#   Best CNN  : Accuracy = 1.0000, Loss = 0.0000
#   ResNet-18 : Accuracy = 1.0000, Loss = 0.0000
#
# CIFAR-10:
#   Best CNN  : Accuracy = 0.7362, Loss = 0.8181
#   ResNet-18 : Accuracy = 0.9361, Loss = 0.2088
